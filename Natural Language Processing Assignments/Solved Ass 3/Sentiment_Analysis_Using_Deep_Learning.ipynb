# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN, GRU, LSTM, Bidirectional, Dense, Dropout
from sklearn.metrics import precision_score, recall_score, f1_score

# %% [markdown]
# # Load Dataset

# %%
data = pd.read_csv('urdu-sentiment-corpus-v1.tsv', sep='\t', header=None, names=['Tweet', 'Class'])
data.head(10)
# Out:
#                                                Tweet  Class
# 0                                              Tweet  Class
# 1  میں نے ایٹم بم بنایا ھے ۔۔۔۔او بھائی ایٹم بمب ...      P
# 2  چندے سے انقلاب اور عمران خان وزیر اعظم نہیں بن...      N
# 3                           ٹویٹر کا خیال کیسے آیا ؟      O
# 4  سرچ انجن گوگل کے نائب صدر نے فضا میں ، 130,000...      P
# 5    ابھی تک اسکی لہریں کبھی کبھی آ جاتی ہیں یار :أْ      P
# 6   گندی زبان اور گٹر جیسے دماغ والے جاهل جیالے ه...      N
# 7  قاتل بھی تم مقتول بھی تم,ظالم بھی ہم اور مظلوم...      N
# 8  ﻧﻮﺭ ﺑﻐﺪﺍﺩ ﮐﯽ ﮔﻠﯿﻮﮞ ﮐﺎ ﮨﮯ ﮨﺮ ﺍﯾﮏ ﮐﺮﻥ ﺍﺱ ﮐﯽ ﻣﺪﯾﻨ...      P
# 9   یہ لفظوں كى شرارت ھے سنبهل کر کچھ بهى لِكهنا ...      P

# %% [markdown]
# # Filter out entries that are not positive or negative

# %%
data = data[(data['Class'] == 'P') | (data['Class'] == 'N')]
data
# Out:
#                                                   Tweet Class
# 1     میں نے ایٹم بم بنایا ھے ۔۔۔۔او بھائی ایٹم بمب ...     P
# 2     چندے سے انقلاب اور عمران خان وزیر اعظم نہیں بن...     N
# 4     سرچ انجن گوگل کے نائب صدر نے فضا میں ، 130,000...     P
# 5       ابھی تک اسکی لہریں کبھی کبھی آ جاتی ہیں یار :أْ     P
# 6      گندی زبان اور گٹر جیسے دماغ والے جاهل جیالے ه...     N
# ...                                                 ...   ...
# 996      اُس آدمی نے اِس سالار کو کافی معقول ٹپ دی ہے ۔     P
# 997   چچا غالب کی روح سے معذرت کے ساتھہم نے مانا کہ ...     P
# 998   واہ جناب واہ! اچھی رہی۔ جناب خود کو فرشتہ سمجو...     P
# 999   اسلام آباد :پی اے ٹی کا دھرنا ختم، صفائی کے کا...     P
# 1000  دنیا نے کس کا راہ وفا میں دیا ہے ساتھتم بھی چل...     P
#
# [979 rows x 2 columns]

# %% [markdown]
# # Encode class labels to numerical values (P: 1, N: 0)

# %%
label_encoder = LabelEncoder()
data['Class'] = label_encoder.fit_transform(data['Class'])

# %% [markdown]
# # Tokenize text

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data['Tweet'])
sequences = tokenizer.texts_to_sequences(data['Tweet'])

# %%
max_sequence_len = max([len(x) for x in sequences])
X = pad_sequences(sequences, maxlen=max_sequence_len)
y = data['Class'].values

# %% [markdown]
# # Split the data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
vocab_size = len(tokenizer.word_index) + 1

def build_model(model_type, input_length, vocab_size, dropout_rate):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=100, input_length=input_length))

    if model_type == 'RNN':
        model.add(SimpleRNN(units=100, dropout=dropout_rate, recurrent_dropout=dropout_rate))
    elif model_type == 'GRU':
        model.add(GRU(units=100, dropout=dropout_rate, recurrent_dropout=dropout_rate))
    elif model_type == 'LSTM':
        model.add(LSTM(units=100, dropout=dropout_rate, recurrent_dropout=dropout_rate))
    elif model_type == 'BiLSTM':
        model.add(Bidirectional(LSTM(units=100, dropout=dropout_rate, recurrent_dropout=dropout_rate)))

    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
rnn_model = build_model('RNN', max_sequence_len, vocab_size, dropout_rate=0.3)
gru_model = build_model('GRU', max_sequence_len, vocab_size, dropout_rate=0.3)
lstm_model = build_model('LSTM', max_sequence_len, vocab_size, dropout_rate=0.3)
bilstm_model = build_model('BiLSTM', max_sequence_len, vocab_size, dropout_rate=0.3)

# %% [markdown]
#  # Training and Evaluation

# %%
from tabulate import tabulate

print("\n ***************** Training and Evaluation *****************")

def train_and_evaluate(model, model_name):
    print(f"\nTraining {model_name} Model:")
    model.fit(X_train, y_train, batch_size=64, epochs=10, validation_split=0.2)
    predictions = model.predict(X_test) > 0.5
    accuracy = model.evaluate(X_test, y_test)[1]
    precision = precision_score(y_test, predictions)
    recall = recall_score(y_test, predictions)
    f_score = f1_score(y_test, predictions)
    return [model_name, accuracy, precision, recall, f_score]

results = []
results.append(train_and_evaluate(rnn_model, " ***************** RNN Model *****************"))
results.append(train_and_evaluate(gru_model, " ***************** ***************** GRU Model *****************"))
results.append(train_and_evaluate(lstm_model, " ***************** LSTM Model *****************"))
results.append(train_and_evaluate(bilstm_model, " ***************** BiLSTM Model *****************"))

print("\nResults:")
print(tabulate(results, headers=["Model", "Accuracy", "Precision", "Recall", "F-score"], tablefmt="grid"))
# Out:
#  ***************** Training and Evaluation *****************
#
# Training  ***************** RNN Model ***************** Model:
# Epoch 1/10
# 10/10 [==============================] - 2s 73ms/step - loss: 0.7330 - accuracy: 0.4906 - val_loss: 0.7084 - val_accuracy: 0.4490
# Epoch 2/10
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6969 - accuracy: 0.5605 - val_loss: 0.7111 - val_accuracy: 0.4218
# Epoch 3/10
# 10/10 [==============================] - 0s 42ms/step - loss: 0.6901 - accuracy: 0.5537 - val_loss: 0.7006 - val_accuracy: 0.4898
# Epoch 4/10
# 10/10 [==============================] - 0s 42ms/step - loss: 0.6839 - accuracy: 0.5656 - val_loss: 0.6956 - val_accuracy: 0.5238
# Epoch 5/10
# 10/10 [==============================] - 0s 41ms/step - loss: 0.6642 - accuracy: 0.6099 - val_loss: 0.6970 - val_accuracy: 0.5170
# Epoch 6/10
# 10/10 [==============================] - 0s 41ms/step - loss: 0.6386 - accuracy: 0.6269 - val_loss: 0.6996 - val_accuracy: 0.4762
# Epoch 7/10
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6131 - accuracy: 0.6865 - val_loss: 0.7005 - val_accuracy: 0.4762
# Epoch 8/10
# 10/10 [==============================] - 0s 46ms/step - loss: 0.5866 - accuracy: 0.7036 - val_loss: 0.7087 - val_accuracy: 0.4898
# Epoch 9/10
# 10/10 [==============================] - 0s 43ms/step - loss: 0.5858 - accuracy: 0.7104 - val_loss: 0.7186 - val_accuracy: 0.4830
# Epoch 10/10
# 10/10 [==============================] - 1s 60ms/step - loss: 0.5189 - accuracy: 0.8109 - val_loss: 0.7211 - val_accuracy: 0.4762
# 8/8 [==============================] - 0s 8ms/step
# 8/8 [==============================] - 0s 8ms/step - loss: 0.7025 - accuracy: 0.5224
#
# Training  ***************** ***************** GRU Model ***************** Model:
# Epoch 1/10
# 10/10 [==============================] - 5s 144ms/step - loss: 0.6938 - accuracy: 0.4872 - val_loss: 0.6943 - val_accuracy: 0.4422
# Epoch 2/10
# 10/10 [==============================] - 1s 101ms/step - loss: 0.6817 - accuracy: 0.7104 - val_loss: 0.6928 - val_accuracy: 0.4898
# Epoch 3/10
# 10/10 [==============================] - 1s 103ms/step - loss: 0.6536 - accuracy: 0.8535 - val_loss: 0.6909 - val_accuracy: 0.5306
# Epoch 4/10
# 10/10 [==============================] - 1s 102ms/step - loss: 0.5302 - accuracy: 0.9097 - val_loss: 0.7347 - val_accuracy: 0.5850
# Epoch 5/10
# 10/10 [==============================] - 1s 100ms/step - loss: 0.3472 - accuracy: 0.8910 - val_loss: 0.7047 - val_accuracy: 0.5510
# Epoch 6/10
# 10/10 [==============================] - 1s 101ms/step - loss: 0.2364 - accuracy: 0.9813 - val_loss: 0.7548 - val_accuracy: 0.5578
# Epoch 7/10
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1035 - accuracy: 0.9796 - val_loss: 0.9706 - val_accuracy: 0.5510
# Epoch 8/10
# 10/10 [==============================] - 2s 175ms/step - loss: 0.0457 - accuracy: 0.9898 - val_loss: 1.2531 - val_accuracy: 0.5986
# Epoch 9/10
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0349 - accuracy: 0.9881 - val_loss: 1.0193 - val_accuracy: 0.5170
# Epoch 10/10
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0216 - accuracy: 0.9966 - val_loss: 1.0758 - val_accuracy: 0.5578
# 8/8 [==============================] - 1s 19ms/step
# 8/8 [==============================] - 0s 20ms/step - loss: 0.8672 - accuracy: 0.6490
#
# Training  ***************** LSTM Model ***************** Model:
# Epoch 1/10
# 10/10 [==============================] - 5s 154ms/step - loss: 0.6934 - accuracy: 0.5043 - val_loss: 0.6963 - val_accuracy: 0.4490
# Epoch 2/10
# 10/10 [==============================] - 1s 112ms/step - loss: 0.6844 - accuracy: 0.5213 - val_loss: 0.6974 - val_accuracy: 0.4558
# Epoch 3/10
# 10/10 [==============================] - 1s 120ms/step - loss: 0.6559 - accuracy: 0.7376 - val_loss: 0.7031 - val_accuracy: 0.4626
# Epoch 4/10
# 10/10 [==============================] - 1s 113ms/step - loss: 0.5435 - accuracy: 0.8552 - val_loss: 0.6987 - val_accuracy: 0.5442
# Epoch 5/10
# 10/10 [==============================] - 1s 114ms/step - loss: 0.3289 - accuracy: 0.9165 - val_loss: 0.7745 - val_accuracy: 0.5714
# Epoch 6/10
# 10/10 [==============================] - 1s 148ms/step - loss: 0.2250 - accuracy: 0.9591 - val_loss: 0.7929 - val_accuracy: 0.5578
# Epoch 7/10
# 10/10 [==============================] - 2s 203ms/step - loss: 0.1365 - accuracy: 0.9710 - val_loss: 0.9027 - val_accuracy: 0.5238
# Epoch 8/10
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0650 - accuracy: 0.9881 - val_loss: 0.9496 - val_accuracy: 0.5306
# Epoch 9/10
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0375 - accuracy: 0.9949 - val_loss: 1.1071 - val_accuracy: 0.5850
# Epoch 10/10
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0259 - accuracy: 0.9966 - val_loss: 1.1797 - val_accuracy: 0.5782
# 8/8 [==============================] - 1s 23ms/step
# 8/8 [==============================] - 0s 24ms/step - loss: 1.0330 - accuracy: 0.6122
#
# Training  ***************** BiLSTM Model ***************** Model:
# Epoch 1/10
# 10/10 [==============================] - 11s 357ms/step - loss: 0.6950 - accuracy: 0.4940 - val_loss: 0.6923 - val_accuracy: 0.5170
# Epoch 2/10
# 10/10 [==============================] - 3s 272ms/step - loss: 0.6855 - accuracy: 0.5980 - val_loss: 0.6971 - val_accuracy: 0.4626
# Epoch 3/10
# 10/10 [==============================] - 2s 231ms/step - loss: 0.6538 - accuracy: 0.6593 - val_loss: 0.6867 - val_accuracy: 0.5170
# Epoch 4/10
# 10/10 [==============================] - 2s 227ms/step - loss: 0.5352 - accuracy: 0.8790 - val_loss: 0.6760 - val_accuracy: 0.5714
# Epoch 5/10
# 10/10 [==============================] - 2s 226ms/step - loss: 0.3067 - accuracy: 0.9353 - val_loss: 0.8383 - val_accuracy: 0.5510
# Epoch 6/10
# 10/10 [==============================] - 3s 297ms/step - loss: 0.1546 - accuracy: 0.9642 - val_loss: 0.8837 - val_accuracy: 0.5714
# Epoch 7/10
# 10/10 [==============================] - 3s 277ms/step - loss: 0.0809 - accuracy: 0.9847 - val_loss: 1.0535 - val_accuracy: 0.5510
# Epoch 8/10
# 10/10 [==============================] - 3s 279ms/step - loss: 0.0516 - accuracy: 0.9830 - val_loss: 1.0335 - val_accuracy: 0.5714
# Epoch 9/10
# 10/10 [==============================] - 2s 222ms/step - loss: 0.0291 - accuracy: 0.9949 - val_loss: 1.2646 - val_accuracy: 0.5442
# Epoch 10/10
# 10/10 [==============================] - 2s 223ms/step - loss: 0.0190 - accuracy: 0.9966 - val_loss: 1.7040 - val_accuracy: 0.5374
# 8/8 [==============================] - 1s 29ms/step
# 8/8 [==============================] - 0s 29ms/step - loss: 1.4327 - accuracy: 0.5959
#
# Results:
# +-----------------------------------------------------------------+------------+-------------+----------+-----------+
# | Model                                                           |   Accuracy |   Precision |   Recall |   F-score |
# +=================================================================+============+=============+==========+===========+
# | ***************** RNN Model *****************                   |   0.522449 |    0.493506 | 0.66087  |  0.565056 |
# +-----------------------------------------------------------------+------------+-------------+----------+-----------+
# | ***************** ***************** GRU Model ***************** |   0.64898  |    0.623932 | 0.634783 |  0.62931  |
# +-----------------------------------------------------------------+------------+-------------+----------+-----------+
# | ***************** LSTM Model *****************                  |   0.612245 |    0.580645 | 0.626087 |  0.60251  |
# +-----------------------------------------------------------------+------------+-------------+----------+-----------+
# | ***************** BiLSTM Model *****************                |   0.595918 |    0.554795 | 0.704348 |  0.62069  |
# +-----------------------------------------------------------------+------------+-------------+----------+-----------+
